# %% [markdown]
# # Expand Spotify playlist with Word2Vec embeddings

# %%
from gensim.models import Word2Vec

model = Word2Vec.load("../models/w2v_v2")
len(set(model.wv.index_to_key))
# Out:
# 281217

# %%
import pandas as pd

df = pd.read_csv("../data/track_uri_mappings.csv")
df = df.astype({"uri": "string", "name": "string", "artist": "string", "album": "string"})
df.head()
# Out:
#                                     uri                         name  \
# 0  spotify:track:58f6PxrFxQ8jEWoDoDVZ9C                    Ease Back
# 1  spotify:track:0WSlOSMLJWoWUpWci9nnRb                  Cissy Strut
# 2  spotify:track:2fkmrMW5eV3VvHeUicem25  People Say - Single Version
# 3  spotify:track:6YBc1KPVqvhB8ugdC9Enkh                Funky Miracle
# 4  spotify:track:0mfQH4OgwV8aQ7JUgVjkhd           Sing A Simple Song
#
#        artist                                    album
# 0  The Meters  Funkify Your Life: The Meters Anthology
# 1  The Meters                               The Meters
# 2  The Meters  Funkify Your Life: The Meters Anthology
# 3  The Meters                            Look-Ka Py Py
# 4  The Meters                               The Meters

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2262292 entries, 0 to 2262291
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   uri     string
#  1   name    string
#  2   artist  string
#  3   album   string
# dtypes: string(4)
# memory usage: 69.0 MB

# %%
df.describe()
# Out:
#                                          uri     name                 artist  \
# count                                2262292  2262285                2262282
# unique                               2262292  1483758                 287739
# top     spotify:track:58f6PxrFxQ8jEWoDoDVZ9C    Intro  Johann Sebastian Bach
# freq                                       1     1559                   5417
#
#                 album
# count         2262285
# unique         571626
# top     Greatest Hits
# freq             2171

# %%
playlist = [
    "spotify:track:0UaMYEvWZi0ZqiDOoHU3YI",
    "spotify:track:6I9VzXrHxO9rA9A5euc8Ak",
    "spotify:track:7uKcScNXuO3MWw6LowBjW1",
    "spotify:track:3dFwpxh2yH7C7p9BGEKLVB",
    "spotify:track:7KXjTSCq5nL1LoYtL7XAwS",
]
missing = [track for track in playlist if track not in model.wv]
assert not missing, "There are tracks missing from model.wv"

# %%
pl_df = pd.DataFrame(playlist, columns=["uri"])
pl_df = pl_df.merge(df, on="uri", how="left")
pl_df
# Out:
#                                     uri  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2  spotify:track:7uKcScNXuO3MWw6LowBjW1
# 3  spotify:track:3dFwpxh2yH7C7p9BGEKLVB
# 4  spotify:track:7KXjTSCq5nL1LoYtL7XAwS
#
#                                          name          artist         album
# 0  Lose Control (feat. Ciara & Fat Man Scoop)   Missy Elliott  The Cookbook
# 1                                       Toxic  Britney Spears   In The Zone
# 2                               One, Two Step           Ciara       Goodies
# 3                                     Goodies           Ciara       Goodies
# 4                                     HUMBLE.  Kendrick Lamar         DAMN.

# %%
import numpy as np

vectors = [model.wv[track] for track in playlist]
centroid = np.mean(vectors, axis=0)

recommendations = model.wv.similar_by_vector(centroid, topn=20)
recommendations = [r for r, _ in recommendations if r not in playlist]
recommendations
# Out:
# ['spotify:track:0RhXv8YzZD1jLiITZiMFe0',
#  'spotify:track:2SUjRDIn23wnKXpO69apxl',
#  'spotify:track:1GH5tpvz5g1ZGKNBPBWkTm',
#  'spotify:track:6gyHX1r0K9fGUjRJKHSRNw',
#  'spotify:track:3fIExmgYdyeMiIKgSUohZ4',
#  'spotify:track:4MPo5nRV5Z1Mdv82DDCitK',
#  'spotify:track:04KTF78FFg8sOHC1BADqbY',
#  'spotify:track:4duAM9CrgspEQyP3B8ZyhT',
#  'spotify:track:6nv0cOrhhVdzUakLrpL77h',
#  'spotify:track:42D1iUtSH8CpktXbnVzAm6',
#  'spotify:track:0aL8yL3w7z7H0l33spCKfj',
#  'spotify:track:2gam98EZKrF9XuOkU13ApN',
#  'spotify:track:3x9LFpV6tzq0qWaBMvY2UT',
#  'spotify:track:2cMTIlktg3M9mXYqCPqw1J',
#  'spotify:track:6RcQOut9fWL6FSqeIr5M1r',
#  'spotify:track:3jagJCUbdqhDSPuxP8cAqF',
#  'spotify:track:0vupCkmy497h49a74Xsxj1']

# %%
rec_df = pd.DataFrame(recommendations, columns=["uri"])
rec_df = rec_df.merge(df, on="uri", how="left")
rec_df
# Out:
#                                      uri  \
# 0   spotify:track:0RhXv8YzZD1jLiITZiMFe0
# 1   spotify:track:2SUjRDIn23wnKXpO69apxl
# 2   spotify:track:1GH5tpvz5g1ZGKNBPBWkTm
# 3   spotify:track:6gyHX1r0K9fGUjRJKHSRNw
# 4   spotify:track:3fIExmgYdyeMiIKgSUohZ4
# 5   spotify:track:4MPo5nRV5Z1Mdv82DDCitK
# 6   spotify:track:04KTF78FFg8sOHC1BADqbY
# 7   spotify:track:4duAM9CrgspEQyP3B8ZyhT
# 8   spotify:track:6nv0cOrhhVdzUakLrpL77h
# 9   spotify:track:42D1iUtSH8CpktXbnVzAm6
# 10  spotify:track:0aL8yL3w7z7H0l33spCKfj
# 11  spotify:track:2gam98EZKrF9XuOkU13ApN
# 12  spotify:track:3x9LFpV6tzq0qWaBMvY2UT
# 13  spotify:track:2cMTIlktg3M9mXYqCPqw1J
# 14  spotify:track:6RcQOut9fWL6FSqeIr5M1r
# 15  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 16  spotify:track:0vupCkmy497h49a74Xsxj1
#
#                                                 name                   artist  \
# 0                                           1,2 Step              Clara Pedro
# 1         Lip Gloss/ No Music - Main Version - clean                 Lil Mama
# 2                                      London Bridge                   Fergie
# 3                                            Run It!              Chris Brown
# 4                                         No Diggity               MC Cologne
# 5                                        Hot in Here                     Crib
# 6                                       Hot In Herre                    Nelly
# 7          2 Step - Feat. T-Pain & Jim Jones - Remix             Lydell Lucky
# 8   Shake Your Pom Pom - R.N. Remix - 32 Counts Edit                   MC Joe
# 9                                          Queen Bee  Gen. Mill$ (feat. Ryan)
# 10                                           Buttons         Deluxe Vagabonds
# 11                                       Promiscuous            Nelly Furtado
# 12            1, 2 Step - Don Candiani Reggaeton Mix                    Ciara
# 13                                         Milkshake                    Kelis
# 14                                    Hollaback Girl             Gwen Stefani
# 15                                           Work It            Missy Elliott
# 16                                         Don't Cha             Busta Rhymes
#
#                                                 album
# 0                                      Aqui Tá-Se Bem
# 1                     VYP - Voice of the Young People
# 2                                       London Bridge
# 3                                             Run It!
# 4                                Move Ya Feet, Vol. 2
# 5                              The Very Best of Nelly
# 6                                          Nellyville
# 7                                      Making Dollars
# 8                          Latin Hits for Summer 2017
# 9                                           Queen Bee
# 10                          Don't Stop the Dirty Talk
# 11                                              Loose
# 12  DVD Bonus Audio (from Goodies. The Videos and ...
# 13                                              Tasty
# 14                              Love Angel Music Baby
# 15                                 Under Construction
# 16                                                PCD

# %%
recommendations = [r for r, _ in model.wv.most_similar(playlist, topn=20)]
recommendations = [r for r in recommendations if r not in playlist]
rec_df = pd.DataFrame(recommendations, columns=["uri"])
rec_df = rec_df.merge(df, on="uri", how="left")
rec_df
# Out:
#                                      uri  \
# 0   spotify:track:0RhXv8YzZD1jLiITZiMFe0
# 1   spotify:track:2SUjRDIn23wnKXpO69apxl
# 2   spotify:track:1GH5tpvz5g1ZGKNBPBWkTm
# 3   spotify:track:6gyHX1r0K9fGUjRJKHSRNw
# 4   spotify:track:4MPo5nRV5Z1Mdv82DDCitK
# 5   spotify:track:3fIExmgYdyeMiIKgSUohZ4
# 6   spotify:track:4duAM9CrgspEQyP3B8ZyhT
# 7   spotify:track:04KTF78FFg8sOHC1BADqbY
# 8   spotify:track:6nv0cOrhhVdzUakLrpL77h
# 9   spotify:track:42D1iUtSH8CpktXbnVzAm6
# 10  spotify:track:0aL8yL3w7z7H0l33spCKfj
# 11  spotify:track:2gam98EZKrF9XuOkU13ApN
# 12  spotify:track:3x9LFpV6tzq0qWaBMvY2UT
# 13  spotify:track:6RcQOut9fWL6FSqeIr5M1r
# 14  spotify:track:2cMTIlktg3M9mXYqCPqw1J
# 15  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 16  spotify:track:4QPILpiFJQ9LPwvltz0qao
# 17  spotify:track:0vupCkmy497h49a74Xsxj1
# 18  spotify:track:5KY7zgFeH2GWoL1zP9mME6
# 19  spotify:track:2WNVqZq1ujhMDlOAqBFkVv
#
#                                                 name  \
# 0                                           1,2 Step
# 1         Lip Gloss/ No Music - Main Version - clean
# 2                                      London Bridge
# 3                                            Run It!
# 4                                        Hot in Here
# 5                                         No Diggity
# 6          2 Step - Feat. T-Pain & Jim Jones - Remix
# 7                                       Hot In Herre
# 8   Shake Your Pom Pom - R.N. Remix - 32 Counts Edit
# 9                                          Queen Bee
# 10                                           Buttons
# 11                                       Promiscuous
# 12            1, 2 Step - Don Candiani Reggaeton Mix
# 13                                    Hollaback Girl
# 14                                         Milkshake
# 15                                           Work It
# 16                                           Ba Bump
# 17                                         Don't Cha
# 18                                  Get Low - Street
# 19                                          My Humps
#
#                           artist  \
# 0                    Clara Pedro
# 1                       Lil Mama
# 2                         Fergie
# 3                    Chris Brown
# 4                           Crib
# 5                     MC Cologne
# 6                   Lydell Lucky
# 7                          Nelly
# 8                         MC Joe
# 9        Gen. Mill$ (feat. Ryan)
# 10              Deluxe Vagabonds
# 11                 Nelly Furtado
# 12                         Ciara
# 13                  Gwen Stefani
# 14                         Kelis
# 15                 Missy Elliott
# 16           The Black Eyed Peas
# 17                  Busta Rhymes
# 18  Lil Jon & The East Side Boyz
# 19           The Black Eyed Peas
#
#                                                 album
# 0                                      Aqui Tá-Se Bem
# 1                     VYP - Voice of the Young People
# 2                                       London Bridge
# 3                                             Run It!
# 4                              The Very Best of Nelly
# 5                                Move Ya Feet, Vol. 2
# 6                                      Making Dollars
# 7                                          Nellyville
# 8                          Latin Hits for Summer 2017
# 9                                           Queen Bee
# 10                          Don't Stop the Dirty Talk
# 11                                              Loose
# 12  DVD Bonus Audio (from Goodies. The Videos and ...
# 13                              Love Angel Music Baby
# 14                                              Tasty
# 15                                 Under Construction
# 16                                    Monkey Business
# 17                                                PCD
# 18                                     Kings Of Crunk
# 19                                    Monkey Business
